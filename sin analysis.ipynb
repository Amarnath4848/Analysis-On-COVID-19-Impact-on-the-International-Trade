# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("2020 2021(full).csv")
data.head()
# Out:
#    Year  Trade Flow Code Trade Flow  Reporter Code            Reporter  \
# 0  2020                1     Import            276             Germany
# 1  2020                1     Import            276             Germany
# 2  2020                1     Import            276             Germany
# 3  2020                1     Import            276             Germany
# 4  2020                1     Import            643  Russian Federation
#
#   Reporter ISO  Partner Code    Partner Partner ISO  Commodity Code  \
# 0          DEU            36  Australia         AUS           70200
# 1          DEU            76     Brazil         BRA           70200
# 2          DEU           156      China         CHN           70200
# 3          DEU           699      India         IND           70200
# 4          RUS           156      China         CHN           70200
#
#                                 Commodity  Qty Unit Code             Qty Unit  \
# 0  Vegetables; tomatoes, fresh or chilled              8  Weight in kilograms
# 1  Vegetables; tomatoes, fresh or chilled              8  Weight in kilograms
# 2  Vegetables; tomatoes, fresh or chilled              8  Weight in kilograms
# 3  Vegetables; tomatoes, fresh or chilled              8  Weight in kilograms
# 4  Vegetables; tomatoes, fresh or chilled              8  Weight in kilograms
#
#         Qty  Netweight (kg)  Trade Value (US$)  Flag
# 0      7200          7200.0               9461     0
# 1      1482          1482.0               4100     0
# 2     16747         16747.0              50501     0
# 3       108           108.0                287     0
# 4  43870910      43870910.0           52723791     0

# %%
print(data)
# Out:
#      Year  Trade Flow Code Trade Flow  Reporter Code            Reporter  \
# 0    2020                1     Import            276             Germany
# 1    2020                1     Import            276             Germany
# 2    2020                1     Import            276             Germany
# 3    2020                1     Import            276             Germany
# 4    2020                1     Import            643  Russian Federation
# ..    ...              ...        ...            ...                 ...
# 471  2020                1     Import            156               China
# 472  2020                2     Export            699               India
# 473  2021                1     Import            410       Rep. of Korea
# 474  2021                2     Export            699               India
# 475  2021                2     Export            699               India
#
#     Reporter ISO  Partner Code    Partner Partner ISO  Commodity Code  \
# 0            DEU            36  Australia         AUS           70200
# 1            DEU            76     Brazil         BRA           70200
# 2            DEU           156      China         CHN           70200
# 3            DEU           699      India         IND           70200
# 4            RUS           156      China         CHN           70200
# ..           ...           ...        ...         ...             ...
# 471          CHN           699      India         IND          520515
# 472          IND           156      China         CHN          520515
# 473          KOR           156      China         CHN          520515
# 474          IND            36  Australia         AUS          520515
# 475          IND           156      China         CHN          520515
#
#                                              Commodity  Qty Unit Code  \
# 0               Vegetables; tomatoes, fresh or chilled              8
# 1               Vegetables; tomatoes, fresh or chilled              8
# 2               Vegetables; tomatoes, fresh or chilled              8
# 3               Vegetables; tomatoes, fresh or chilled              8
# 4               Vegetables; tomatoes, fresh or chilled              8
# ..                                                 ...            ...
# 471  Cotton yarn; (not sewing thread), single, of u...              8
# 472  Cotton yarn; (not sewing thread), single, of u...              8
# 473  Cotton yarn; (not sewing thread), single, of u...              8
# 474  Cotton yarn; (not sewing thread), single, of u...              8
# 475  Cotton yarn; (not sewing thread), single, of u...              8
#
#                 Qty Unit       Qty  Netweight (kg)  Trade Value (US$)  Flag
# 0    Weight in kilograms      7200          7200.0               9461     0
# 1    Weight in kilograms      1482          1482.0               4100     0
# 2    Weight in kilograms     16747         16747.0              50501     0
# 3    Weight in kilograms       108           108.0                287     0
# 4    Weight in kilograms  43870910      43870910.0           52723791     0
# ..                   ...       ...             ...                ...   ...
# 471  Weight in kilograms        48            48.0                487     0
# 472  Weight in kilograms     11848         11848.0              38094     0
# 473  Weight in kilograms       447           447.0               6789     0
# 474  Weight in kilograms         2             2.0                 17     0
# 475  Weight in kilograms     18109         18109.0              57243     0
#
# [476 rows x 17 columns]

# %%
data.dropna()
# Out:
#      Year  Trade Flow Code Trade Flow  Reporter Code            Reporter  \
# 0    2020                1     Import            276             Germany
# 1    2020                1     Import            276             Germany
# 2    2020                1     Import            276             Germany
# 3    2020                1     Import            276             Germany
# 4    2020                1     Import            643  Russian Federation
# ..    ...              ...        ...            ...                 ...
# 471  2020                1     Import            156               China
# 472  2020                2     Export            699               India
# 473  2021                1     Import            410       Rep. of Korea
# 474  2021                2     Export            699               India
# 475  2021                2     Export            699               India
#
#     Reporter ISO  Partner Code    Partner Partner ISO  Commodity Code  \
# 0            DEU            36  Australia         AUS           70200
# 1            DEU            76     Brazil         BRA           70200
# 2            DEU           156      China         CHN           70200
# 3            DEU           699      India         IND           70200
# 4            RUS           156      China         CHN           70200
# ..           ...           ...        ...         ...             ...
# 471          CHN           699      India         IND          520515
# 472          IND           156      China         CHN          520515
# 473          KOR           156      China         CHN          520515
# 474          IND            36  Australia         AUS          520515
# 475          IND           156      China         CHN          520515
#
#                                              Commodity  Qty Unit Code  \
# 0               Vegetables; tomatoes, fresh or chilled              8
# 1               Vegetables; tomatoes, fresh or chilled              8
# 2               Vegetables; tomatoes, fresh or chilled              8
# 3               Vegetables; tomatoes, fresh or chilled              8
# 4               Vegetables; tomatoes, fresh or chilled              8
# ..                                                 ...            ...
# 471  Cotton yarn; (not sewing thread), single, of u...              8
# 472  Cotton yarn; (not sewing thread), single, of u...              8
# 473  Cotton yarn; (not sewing thread), single, of u...              8
# 474  Cotton yarn; (not sewing thread), single, of u...              8
# 475  Cotton yarn; (not sewing thread), single, of u...              8
#
#                 Qty Unit       Qty  Netweight (kg)  Trade Value (US$)  Flag
# 0    Weight in kilograms      7200          7200.0               9461     0
# 1    Weight in kilograms      1482          1482.0               4100     0
# 2    Weight in kilograms     16747         16747.0              50501     0
# 3    Weight in kilograms       108           108.0                287     0
# 4    Weight in kilograms  43870910      43870910.0           52723791     0
# ..                   ...       ...             ...                ...   ...
# 471  Weight in kilograms        48            48.0                487     0
# 472  Weight in kilograms     11848         11848.0              38094     0
# 473  Weight in kilograms       447           447.0               6789     0
# 474  Weight in kilograms         2             2.0                 17     0
# 475  Weight in kilograms     18109         18109.0              57243     0
#
# [475 rows x 17 columns]

# %%
row = {'Reporter', 'Trade Value (US$)'}

# %%
data.plot.bar(x='Reporter', y='Trade Value (US$)')
# Out:
# <Axes: xlabel='Reporter'>

# %%
df = data["Trade Value (US$)"]
labels = data["Reporter"]
plt.figure(figsize=(7,7))
plt.pie(df, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85, shadow =True)
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=12)
plt.title("Distribution of the Trade", fontsize=20)
plt.show()

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Data acquisition of the movies dataset
df_trade=pd.read_csv('trade dataset.csv')
df_trade.columns =['Year','Trade Flow Code','Trade Flow','Reporter Code','Reporter','Reporter ISO','Partner Code','Partner','Partner ISO','Commodity Code','Commodity','Qty Unit Code','Qty Unit','Qty','Netweight(kg)','Trade Value (US$)','Flag']
df_trade.columns
df_trade.dropna(inplace=True)
df_trade.head()
# Out:
#    Year  Trade Flow Code Trade Flow  Reporter Code            Reporter  \
# 0  2019                1     Import            276             Germany
# 1  2019                1     Import            276             Germany
# 2  2019                1     Import            276             Germany
# 3  2019                1     Import            643  Russian Federation
# 4  2019                2     Export            643  Russian Federation
#
#   Reporter ISO  Partner Code    Partner Partner ISO  Commodity Code  \
# 0          DEU            36  Australia         AUS           70200
# 1          DEU            76     Brazil         BRA           70200
# 2          DEU           156      China         CHN           70200
# 3          RUS           156      China         CHN           70200
# 4          RUS           699      India         IND           70200
#
#                                 Commodity  Qty Unit Code             Qty Unit  \
# 0  Vegetables; tomatoes, fresh or chilled              8  Weight in kilograms
# 1  Vegetables; tomatoes, fresh or chilled              8  Weight in kilograms
# 2  Vegetables; tomatoes, fresh or chilled              8  Weight in kilograms
# 3  Vegetables; tomatoes, fresh or chilled              8  Weight in kilograms
# 4  Vegetables; tomatoes, fresh or chilled              8  Weight in kilograms
#
#         Qty  Netweight(kg)  Trade Value (US$)  Flag
# 0      3372         3372.0               4391     0
# 1     46719        46719.0              27134     0
# 2     25199        25199.0              68762     0
# 3  69386320     69386320.0           84116572     0
# 4       634          634.0               1592     0

# %%
df = df_trade[df_trade['Year']==2019][df_trade["Reporter"]=="Germany"]
df
# Out:
# <ipython-input-39-9b329331b575>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df_trade[df_trade['Year']==2019][df_trade["Reporter"]=="Germany"]
#      Year  Trade Flow Code Trade Flow  Reporter Code Reporter Reporter ISO  \
# 0    2019                1     Import            276  Germany          DEU
# 1    2019                1     Import            276  Germany          DEU
# 2    2019                1     Import            276  Germany          DEU
# 20   2019                1     Import            276  Germany          DEU
# 44   2019                1     Import            276  Germany          DEU
# 45   2019                1     Import            276  Germany          DEU
# 63   2019                1     Import            276  Germany          DEU
# 64   2019                2     Export            276  Germany          DEU
# 65   2019                1     Import            276  Germany          DEU
# 66   2019                2     Export            276  Germany          DEU
# 67   2019                1     Import            276  Germany          DEU
# 68   2019                2     Export            276  Germany          DEU
# 69   2019                1     Import            276  Germany          DEU
# 70   2019                2     Export            276  Germany          DEU
# 158  2019                1     Import            276  Germany          DEU
# 159  2019                2     Export            276  Germany          DEU
# 160  2019                1     Import            276  Germany          DEU
# 161  2019                2     Export            276  Germany          DEU
# 162  2019                1     Import            276  Germany          DEU
# 163  2019                2     Export            276  Germany          DEU
# 164  2019                1     Import            276  Germany          DEU
# 240  2019                1     Import            276  Germany          DEU
# 241  2019                2     Export            276  Germany          DEU
# 242  2019                1     Import            276  Germany          DEU
# 243  2019                2     Export            276  Germany          DEU
# 244  2019                1     Import            276  Germany          DEU
# 245  2019                2     Export            276  Germany          DEU
# 246  2019                1     Import            276  Germany          DEU
# 247  2019                2     Export            276  Germany          DEU
# 344  2019                1     Import            276  Germany          DEU
# 345  2019                1     Import            276  Germany          DEU
# 383  2019                1     Import            276  Germany          DEU
# 384  2019                2     Export            276  Germany          DEU
# 385  2019                1     Import            276  Germany          DEU
# 386  2019                2     Export            276  Germany          DEU
# 387  2019                1     Import            276  Germany          DEU
# 388  2019                2     Export            276  Germany          DEU
# 389  2019                1     Import            276  Germany          DEU
# 390  2019                2     Export            276  Germany          DEU
#
#      Partner Code    Partner Partner ISO  Commodity Code  \
# 0              36  Australia         AUS           70200
# 1              76     Brazil         BRA           70200
# 2             156      China         CHN           70200
# 20             36  Australia         AUS           80211
# 44             36  Australia         AUS           80910
# 45            156      China         CHN           80910
# 63             36  Australia         AUS             910
# 64             36  Australia         AUS             910
# 65             76     Brazil         BRA             910
# 66             76     Brazil         BRA             910
# 67            156      China         CHN             910
# 68            156      China         CHN             910
# 69            699      India         IND             910
# 70            699      India         IND             910
# 158            36  Australia         AUS            1006
# 159            36  Australia         AUS            1006
# 160            76     Brazil         BRA            1006
# 161            76     Brazil         BRA            1006
# 162           156      China         CHN            1006
# 163           156      China         CHN            1006
# 164           699      India         IND            1006
# 240            36  Australia         AUS            1905
# 241            36  Australia         AUS            1905
# 242            76     Brazil         BRA            1905
# 243            76     Brazil         BRA            1905
# 244           156      China         CHN            1905
# 245           156      China         CHN            1905
# 246           699      India         IND            1905
# 247           699      India         IND            1905
# 344           156      China         CHN          500710
# 345           699      India         IND          500710
# 383            36  Australia         AUS              51
# 384            36  Australia         AUS              51
# 385            76     Brazil         BRA              51
# 386            76     Brazil         BRA              51
# 387           156      China         CHN              51
# 388           156      China         CHN              51
# 389           699      India         IND              51
# 390           699      India         IND              51
#
#                                              Commodity  Qty Unit Code  \
# 0               Vegetables; tomatoes, fresh or chilled              8
# 1               Vegetables; tomatoes, fresh or chilled              8
# 2               Vegetables; tomatoes, fresh or chilled              8
# 20     Nuts, edible; almonds, fresh or dried, in shell              8
# 44                      Fruit, edible; apricots, fresh              8
# 45                      Fruit, edible; apricots, fresh              8
# 63   Ginger, saffron, tumeric (curcuma), thyme, bay...              8
# 64   Ginger, saffron, tumeric (curcuma), thyme, bay...              8
# 65   Ginger, saffron, tumeric (curcuma), thyme, bay...              8
# 66   Ginger, saffron, tumeric (curcuma), thyme, bay...              8
# 67   Ginger, saffron, tumeric (curcuma), thyme, bay...              8
# 68   Ginger, saffron, tumeric (curcuma), thyme, bay...              8
# 69   Ginger, saffron, tumeric (curcuma), thyme, bay...              8
# 70   Ginger, saffron, tumeric (curcuma), thyme, bay...              8
# 158                                               Rice              8
# 159                                               Rice              8
# 160                                               Rice              8
# 161                                               Rice              8
# 162                                               Rice              8
# 163                                               Rice              8
# 164                                               Rice              8
# 240  Bread, pastry, cakes, biscuits, other bakers' ...              8
# 241  Bread, pastry, cakes, biscuits, other bakers' ...              8
# 242  Bread, pastry, cakes, biscuits, other bakers' ...              8
# 243  Bread, pastry, cakes, biscuits, other bakers' ...              8
# 244  Bread, pastry, cakes, biscuits, other bakers' ...              8
# 245  Bread, pastry, cakes, biscuits, other bakers' ...              8
# 246  Bread, pastry, cakes, biscuits, other bakers' ...              8
# 247  Bread, pastry, cakes, biscuits, other bakers' ...              8
# 344                   Silk; woven fabrics of noil silk              8
# 345                   Silk; woven fabrics of noil silk              8
# 383  Wool, fine or coarse animal hair; horsehair ya...              1
# 384  Wool, fine or coarse animal hair; horsehair ya...              1
# 385  Wool, fine or coarse animal hair; horsehair ya...              1
# 386  Wool, fine or coarse animal hair; horsehair ya...              1
# 387  Wool, fine or coarse animal hair; horsehair ya...              1
# 388  Wool, fine or coarse animal hair; horsehair ya...              1
# 389  Wool, fine or coarse animal hair; horsehair ya...              1
# 390  Wool, fine or coarse animal hair; horsehair ya...              1
#
#                 Qty Unit       Qty  Netweight(kg)  Trade Value (US$)  Flag
# 0    Weight in kilograms      3372         3372.0               4391     0
# 1    Weight in kilograms     46719        46719.0              27134     0
# 2    Weight in kilograms     25199        25199.0              68762     0
# 20   Weight in kilograms       277          277.0                944     0
# 44   Weight in kilograms      1625         1625.0              14436     0
# 45   Weight in kilograms      2465         2465.0               4278     0
# 63   Weight in kilograms      9416         9416.0             140444     6
# 64   Weight in kilograms     48840        48840.0             376809     6
# 65   Weight in kilograms    878898       878898.0            4886421     6
# 66   Weight in kilograms      9630         9630.0              54330     0
# 67   Weight in kilograms  14145824     14145824.0           31937538     6
# 68   Weight in kilograms    130004       130004.0             874385     6
# 69   Weight in kilograms   6051659      6051659.0           14347496     6
# 70   Weight in kilograms      3331         3331.0              48948     6
# 158  Weight in kilograms     21360        21360.0              22195     0
# 159  Weight in kilograms      7839         7839.0               7402     0
# 160  Weight in kilograms     81401        81401.0              80134     0
# 161  Weight in kilograms       694          694.0                896     0
# 162  Weight in kilograms    125692       125692.0             153559     0
# 163  Weight in kilograms        35           35.0                169     0
# 164  Weight in kilograms  23855998     23855998.0           32002103     6
# 240  Weight in kilograms     49821        49821.0             192219     6
# 241  Weight in kilograms   7231251      7231251.0           28339433     0
# 242  Weight in kilograms      7737         7737.0              48880     6
# 243  Weight in kilograms   2414601      2414601.0            8106424     0
# 244  Weight in kilograms   4213224      4213224.0            8371816     6
# 245  Weight in kilograms   3738589      3738589.0           18344988     6
# 246  Weight in kilograms    410225       410225.0            1547544     6
# 247  Weight in kilograms    109390       109390.0             320922     0
# 344  Weight in kilograms      1613         1613.0             158998     6
# 345  Weight in kilograms      2546         2546.0             146878     6
# 383          No Quantity         0            0.0            9170595     4
# 384          No Quantity         0            0.0             348725     4
# 385          No Quantity         0            0.0            1161687     0
# 386          No Quantity         0            0.0               3876     0
# 387          No Quantity         0            0.0           80441637     4
# 388          No Quantity         0            0.0            2434216     4
# 389          No Quantity         0            0.0            2706989     4
# 390          No Quantity         0            0.0             173621     0

# %%
df = df_trade[df_trade['Year']==2019]
frequency = np.unique(df["Trade Flow"])
country = np.unique(df["Reporter"])
countryList = {}
for i in country:
  list = {}
  for j in frequency:
    list[j] = len(df[(df["Trade Flow"]==j) & (df["Reporter"]==i)])
  
  countryList[i] = list
countryList
dff = pd.DataFrame(countryList).transpose()
dff["Country"] = dff.index
dff
# Out:
#                     Export  Import  Re-Import             Country
# China                   15      16          4               China
# Germany                 15      24          0             Germany
# India                   16      14          0               India
# Rep. of Korea           14      18          0       Rep. of Korea
# Russian Federation      11      14          0  Russian Federation

# %%
dff.plot(x="Country",
        kind='bar',
        stacked=False,
        title='Grouped Bar Graph with dataframe')
# Out:
# <Axes: title={'center': 'Grouped Bar Graph with dataframe'}, xlabel='Country'>

# %%
df = df_trade[df_trade['Year']==2021]
frequency = np.unique(df["Trade Flow"])
country = np.unique(df["Reporter"])
countryList = {}
for i in country:
  list = {}
  for j in frequency:
    list[j] = len(df[(df["Trade Flow"]==j) & (df["Reporter"]==i)])
  
  countryList[i] = list
countryList
dff = pd.DataFrame(countryList).transpose()
dff["Country"] = dff.index
dff
# Out:
#                     Export  Import  Re-Import             Country
# China                   13      16          4               China
# Germany                 16      21          0             Germany
# India                   15      12          0               India
# Rep. of Korea           13      22          0       Rep. of Korea
# Russian Federation      13      16          0  Russian Federation

# %%
dff.plot(x="Country",
        kind='bar',
        stacked=False,
        title='Grouped Bar Graph with dataframe')
# Out:
# <Axes: title={'center': 'Grouped Bar Graph with dataframe'}, xlabel='Country'>

# %%
df = df_trade[df_trade['Year']==2019][df_trade["Trade Flow"]=="Import"][df_trade["Reporter"]=="India"][df_trade["Commodity"]=="Rice"]
df
# Out:
# <ipython-input-44-ee31968a9434>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df_trade[df_trade['Year']==2019][df_trade["Trade Flow"]=="Import"][df_trade["Reporter"]=="India"][df_trade["Commodity"]=="Rice"]
#      Year  Trade Flow Code Trade Flow  Reporter Code Reporter Reporter ISO  \
# 177  2019                1     Import            699    India          IND
# 179  2019                1     Import            699    India          IND
# 181  2019                1     Import            699    India          IND
#
#      Partner Code    Partner Partner ISO  Commodity Code Commodity  \
# 177            36  Australia         AUS            1006      Rice
# 179            76     Brazil         BRA            1006      Rice
# 181           156      China         CHN            1006      Rice
#
#      Qty Unit Code             Qty Unit     Qty  Netweight(kg)  \
# 177              8  Weight in kilograms  148000       148000.0
# 179              8  Weight in kilograms       4            4.0
# 181              8  Weight in kilograms       2            2.0
#
#      Trade Value (US$)  Flag
# 177              48149     0
# 179                237     0
# 181                 57     0

# %%
df = df_trade[df_trade['Year']==2021][df_trade["Trade Flow"]=="Import"][df_trade["Reporter"]=="India"][df_trade["Commodity"]=="Rice"]
df
# Out:
# <ipython-input-45-0fe4e461c613>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df_trade[df_trade['Year']==2021][df_trade["Trade Flow"]=="Import"][df_trade["Reporter"]=="India"][df_trade["Commodity"]=="Rice"]
#      Year  Trade Flow Code Trade Flow  Reporter Code Reporter Reporter ISO  \
# 227  2021                1     Import            699    India          IND
# 229  2021                1     Import            699    India          IND
#
#      Partner Code    Partner Partner ISO  Commodity Code Commodity  \
# 227            36  Australia         AUS            1006      Rice
# 229            76     Brazil         BRA            1006      Rice
#
#      Qty Unit Code             Qty Unit    Qty  Netweight(kg)  \
# 227              8  Weight in kilograms  63800        63800.0
# 229              8  Weight in kilograms      7            7.0
#
#      Trade Value (US$)  Flag
# 227              35199     0
# 229                345     0
